# %%
#by descriptive stats - we should able to do
  #1. Which plot should we make for data
  #2. Data cleaning
  #3. Finding issues in data such as outliers 
  #4. which ml algorithm should we apply

# %%
#Inferential Stats - 
#1. confidence interval
#2. Hypothesis testing

# %%
#first there is population and sample - suppose zomato customers are population
#We cant study population always cause :
  #it can be very huge
  #Time consuming 
  #Expensive
#we take sample from population to solve this problem 
 #sample should not be huge and not very small as well.
 #it should be large enough to represent all properties of population.

# %%
#The population is very large hence we have to infer the sample data or output to the population, 
#hence inferential statistics name has come. 

#In simple words the population is very very huge. 
'''We can't find the mean or do operations on it as long as it is very big 
and because of that it can be time-consuming and very very expensive.
Hence we take a small sample of the population that helps us to mimic the population. 
The sample usually mimics the population and helps us to reduce the time and doesn't make it that expensive as well.
Simply if you want the mean of the population, then we take the sample and then take the mean of that sample.
We suppose that the mean of the sample is equivalent to the mean of the population. 
'''
# Out:
# "We can't find the mean or do operations on it as long as it is very big \nand because of that it can be time-consuming and very very expensive.\nHence we take a small sample of the population that helps us to mimic the population. \nThe sample usually mimics the population and helps us to reduce the time and doesn't make it that expensive as well.\nSimply if you want the mean of the population, then we take the sample and then take the mean of that sample.\nWe suppose that the mean of the sample is equivalent to the mean of the population. \n"

# %% [markdown]
# ![image.png](attachment:9fa46162-ab84-4adb-bd6a-b085c06b6b24.png)

# %%
#the population output is not always equal to sample 

#if we say the population [mean = sample mean] , this is called point estimation (totally equal)
  #it is not very accurate

# %%
#due to low accuracy we adjust the above formula

# %% [markdown]
# ![image.png](attachment:baeffd25-6c19-4200-ba59-29fd5efd559b.png)

# %%
#Marginal error is the maximum error we can make while making sample mean
#took 2 years as example

# %% [markdown]
# ![image.png](attachment:b7003b98-4b5b-4d92-8ef9-e009fc1968a3.png)

# %%
#but a mean value cannot be equal to a range - it is not logically correct
#its not population mean but confidence interval

# %% [markdown]
# ![image.png](attachment:71c51eb0-79b8-4d5b-b400-18877cb2f367.png)

# %%
#hence population mean will be fall in this confidence interval
#we will never found the exact value of population mean in this interval

#bigger the interval bigger the confidence 
#smaller the interval smaller the confidence

# %% [markdown]
# ![image.png](attachment:5931f7c1-4615-4108-83ff-b32cba54542c.png)

# %%
#more the co0nfidence more the interval range 
#sample mean is fixed, we have to change the margin of error

# %%
#if we want to be 100% of confident the interval will be so huge that it'll be useless!
#90 percentage is more usefull than 99% in real world
#depending on the problem we will take confidence levels accordingly

# %%
#Normal Distribution - mean mode median is equal and symmetric

# %% [markdown]
# ![image.png](attachment:d97e4f9c-6814-4326-9e59-d4873057c3a2.png)

# %%
#here z is z score

# %% [markdown]
# ![image.png](attachment:301395d2-d94a-48e1-b4d6-7f81f5b8bcfc.png)

# %% [markdown]
# ![image.png](attachment:723e7863-87d1-40f9-91dc-10134f18b0e5.png)

# %% [markdown]
# ![WhatsApp Image 2026-06-28 at 12.05.11 AM.jpeg](attachment:c7f21507-e802-4f27-9c09-4ed34f230a52.jpeg)
# ![WhatsApp Image 2026-06-28 at 12.05.12 AM.jpeg](attachment:0c5572fa-85d4-4b77-9ea2-85669de24e1e.jpeg)
# ![WhatsApp Image 2026-06-28 at 12.05.12 AM (1).jpeg](attachment:cfe067c6-2796-4e9c-8372-edcf0378ee56.jpeg)
# ![WhatsApp Image 2026-06-28 at 12.05.12 AM (2).jpeg](attachment:e2644bff-eac2-451d-871f-8a43ae88d369.jpeg)
# ![WhatsApp Image 2026-06-28 at 12.05.13 AM.jpeg](attachment:7fa735b6-5939-46fa-a731-542e70523d18.jpeg)
