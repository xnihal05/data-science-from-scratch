# %%
# Statistics or stats 
#It is a branch of mathematics that deals with collecting , organizing, analysis, interpreting,and presenting of data

# %%
#In simple words - it means to make the sense of data!

# %%
#need of statictics 
#1. To make the sense of data
#2. Undderstanding patterns'
#3. Make Predictions
#4. Use it for better decision
#5. Find some relationship in data
#6. To test ideas

# %%
#Types of Stats=
#1. Descriptive stats
  # Summerize and describe the characterstics of data
  # Used to analyze and present the data

#2.  Inferential stats
  #Draw some conclusion and make predictions from the data

# %%
#1. Descriptive stats - it'll do the mathematical operations
  #It is divided into two parts

    #a. Measure of central tendency
      #Mean
      #Mode
      #Median
 
    #b. Measure of dispersion tendency - tells how split is our data is!
      #range
      #variance
      #standard daviasion
      #percentile
      #correlation
      #outliers
      #quartiles

# %%
 #a. Measure of central tendency

#1. mean - average value of data
data= [23,342,23,34,43,54,232,23,33,44,24]
#mean - (sum of all datapoints) / (number of datapoints)
#mean = (sum of data)/(length of data)
sum(data)
# Out:
# 875

# %%
len(data)
# Out:
# 11

# %%
mean = sum(data)/len(data)
mean
# Out:
# 79.54545454545455

# %%
#very long, just use libraries
import numpy as np
import statistics as stats

# %%
ans = np.mean(data)

# %%
ans
# Out:
# 79.54545454545455

# %%
ans2= stats.mean(data)

# %%
ans2
# Out:
# 79.54545454545455

# %%
#we can get by stats as well as by numpy, for mathematics we'll go with stats only!
# if the answer coming 5.0 smth stats will make it 5 as int instead of float

# %%
#2. Median - middle value of the data (exact middle value of data)
 #data = [3,4,5,3,4,2,6]
 #first we have to sort the data
 #i have to check the lenght of data
 #length = 7
 # i have to check if the length is even or odd
 # lenth is odd 
 # formula = (n+1)/2 where n is the length of the data

# %%
data = [3,4,5,3,4,2,6]
med = np.median(data)
print(med)
# Out:
# 4.0

# %%
data = [3,4,5,3,4,2,6]
med = stats.median(data)
print(med)
# Out:
# 4

# %%
#Lets see for even number of elements
#data=[ 1,2,4,5,6,7,8,9]
# first we have to sort the data then we'll see even number of values sorted
# median = mean of 5,6 - mean of (find n/2th term and (n/2)+1 term )
# 5+6/2 = 11/2 = 5.5
data3 =[ 1,2,4,5,6,7,8,9]
median = stats.median(data3)
median
# Out:
# 5.5

# %%
#3. mode- the value that appears most of the time
# data=[1,2,13,1,1,2,23]
#i have to calculate the frwquency 
# 1- 3 times
# 2- 2 times
# 13- 1 time
# 23 - 1 time
#single mode - the first occurance of most repeated value ( frequent value)
#highest frequent value is 1 - (most occuring value)
#hence mode is 1
data=[1,2,13,1,1,2,23]
mode= stats.mode(data)
mode
# Out:
# 1

# %%
#multimode - whenever you having more than one modes (frequent values)
data=[1,2,13,1,1,2,23,23,23]
# 1- 3 times
# 2- 2 times
# 13- 1 time
# 23 - 3 time
mode= stats.mode(data)
mode #it'll give first value only
# Out:
# 1

# %%
multimode= stats.multimode(data)
multimode #gives all , which is same not only first!
# Out:
# [1, 23]

# %%
data=[1, 23,23,23 , 2,13,1,1,2]
stats.mode(data) # which comes first serves first kind of thing
# Out:
# 1

# %%
data=[23, 23,1,23 , 2,13,1,1,2]
stats.mode(data)
# Out:
# 23

# %%
data=[1,2,3,4,5]
stats.mode(data)
# Out:
# 1

# %%
stats.multimode(data)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Population, sample ->
#example - total population of india is 1.8 billion - so we want to check in mumbai only there is 50 crore
#hence sample is mumbai population and population is entire dataset
#or we can say sample is a subset of population!

# %%
#it depends on our sample , sample can make outcome bias aswell.
#example - punjab loves roti more than rice and west bbengal loves rice more than roti
#hence if we take sample of punjab only- it can be like india loves roti more than rice - vice versa for west bengal
#Hence we have to take care of it

# %%
#types of sample
#1. Random Sampling -> Every datapoints has equal chance to get selected
#df.sample() - we have already used it

# %%
import random
population = [2,4,23,26,242,23,23,12,54,675,23,23,2,425,457,243,12]
sample= random.sample(population,5) #population, number of sample we needed

# %%
sample
# Out:
# [23, 23, 2, 4, 425]

# %%
#2. systematic Sampling ->  the value are selected for every kth values
#suppose there are 10 values and our kth value given is 4 then every 4th value is taken!

# %%
population = [2,4,23,26,242,23,23,12,54,675,23,23,2,425,457,243,12]
#i want every 3rd element hence k=3
sample= population[2::3]
sample
# Out:
# [23, 23, 54, 23, 457]

# %%
#3. Stratified sampling - dividing the population into groups then we will take the random sample from the groups
  #its better cause in random there is possibility that if we take random 1cr value all are from punjab for (india)population

# %%
data = {
    'students' : ['a','b','c','d','e','f','g','h'],
    'gender' : ['male','female','female','male','male','female','male','female'],
    'marks' : [76,89,67,56,87,67,54,98]
}

# %%
import pandas as pd
dp = pd.DataFrame(data)
dp
#seperate them into groups (male and females)
male = dp[dp['gender']=='male']

# %%
male
# Out:
#   students gender  marks
# 0        a   male     76
# 3        d   male     56
# 4        e   male     87
# 6        g   male     54

# %%
female = dp[dp['gender']=='female']

# %%
female
# Out:
#   students  gender  marks
# 1        b  female     89
# 2        c  female     67
# 5        f  female     67
# 7        h  female     98

# %%
male_sample = male.sample(2)

# %%
female_sample = female.sample(2)

# %%
str_sample = pd.concat([male_sample,female_sample]) #it will concatinate data which will be inside the list

# %%
str_sample
# Out:
#   students  gender  marks
# 0        a    male     76
# 6        g    male     54
# 7        h  female     98
# 2        c  female     67

# %%
 #b. Measure of dispersion
#The spread of data- it'll tell us about the spread of the data

      #range
      #variance
      #standard daviasion\
      #percentile
      #correlation
      #outliers
      #quartiles

# %%
#1. range- tells about the difference between the maximum value and the minimum value called range
#population = [2,4,23,26,242,23,23,12,54,675,23,23,2,425,457,243,12]
# MAX value = 675
# MIN value = 2
#Range = MAX - MIN = 673
population = [2,4,23,26,242,23,23,12,54,675,23,23,2,425,457,243,12]
max1 = np.max(population)
min1 = np.min(population)
range1 = max1 - min1
range1
# Out:
# 673

# %%
#we wont do this - we will use ptp 
range2 = np.ptp(population) #ptp means peak to peak
range2
# Out:
# 673

# %%
#Mini assignment
data = [10,29,31,12,23,5,32,65,34,37,67,87,56,47,86,50,98,23,82,46,45]
# Calculate ->
# Mean
# Median
# Mode
# Multimode
# Random sample with 6 values
# Systematic sample with every 2nd value
# RangeCopied!

# %%
mean = stats.mean(data)
mean
# Out:
# 45.95238095238095

# %%
median = stats.median(data)
median
# Out:
# 45

# %%
mode = stats.mode(data)
mode
# Out:
# 23

# %%
multimode= stats.multimode(data)
multimode
# Out:
# [23]

# %%
sample = random.sample(data,6)
sample
# Out:
# [32, 12, 67, 87, 5, 34]

# %%
sample2 = data[2::2]
sample2
# Out:
# [31, 23, 32, 34, 67, 56, 86, 98, 82, 45]

# %%
range9= np.ptp(data)
range9
# Out:
# 93

# %%
#2. Variance
  #- quantifies the spread of data around mean
data=[25,30,35,55,60,65,70]
ans = np.var(data)
ans
# Out:
# 283.6734693877551

# %%
data=[1,2,3,4,5]
#mean is 3 
#variance (sumission(xi - xmean)^2)/total number of values - we square so we wont get minus value leads to 0 
ans = np.var(data)
ans
# Out:
# 2.0

# %% [markdown]
# ![image.png](attachment:50105357-70ce-47b4-9ef5-98774739326e.png)

# %%
#unit of variance is in square of orignal unit system

# %%
#3. STandard Deviation -> it is the square root of the variance
#it indicates how much the individual datapoint is deviated from the mean
data=[25,30,35,55,60,65,70]
std_ans = np.std(data)
std_ans
#its units are km,m,etc not in square cause square root cancelling it!
# Out:
# 16.84260874650228

# %%
#in stats library we are getting different  answer and in numpy library its differnet
data=[1,2,3,4,5]
np.var(data)
# Out:
# 2.0

# %%
stats.variance(data)
# Out:
# 2.5

# %%
stats.stdev(data)
# Out:
# 1.5811388300841898

# %%
np.std(data)
# Out:
# 1.4142135623730951

# %% [markdown]
# #Numpy is calculating on population and stats is calculating over sample
# #formulas are different
# ![image.png](attachment:b4d79295-63a7-4533-9c2a-87057ac61a76.png)

# %%
'''
we generally use sample variance (stats) one because its work in sample - not actual population cause 
working on actual population might be tough if the data is very very big 
we assume that the sample will give us desired outcome as for population and that data output will be sufficient
Hence the formula is n-1 for all either for variance and standard deviation
'''
# Out:
# '\nwe generally use sample variance (stats) one because its work in sample - not actual population cause \nworking on actual population might be tough if the data is very very big \nwe assume that the sample will give us desired outcome as for population and that data output will be sufficient\nHence the formula is n-1 for all either for variance and standard deviation\n'

# %%
#4. percentile - indicates the percentage of data values that fall at or below a particular point
#Percentage - 95% means i scored 95 out of 100
#Percentile - 95% means 95% of students are fall or below me

# %%
data = [10,30,45,65,23,45,67,87]
#60 percentile
ans = np.percentile(data,60)
ans
#6 values are lying below 49
# Out:
# 49.0

# %%
#40 percentile
ans=np.percentile(data,40)
ans
# Out:
# 42.00000000000001

# %%
#5. Quartile -> 
# First Quartile Q1 - 25% of data
# Second Quartile Q2 - 50% of data
# Third Quartile Q3 - 75% of data

# %% [markdown]
# ![image.png](attachment:5f417793-1a6c-41da-b887-0c370a112061.png)

# %%
data6=[43,65,67,78,65,34,89,65,34]
q1= np.percentile(data6,25)
q2= np.percentile(data6,50)
q3= np.percentile(data6,75)
print('Quartile 1 :',q1)
print('Quartile 2 :',q2)
print('Quartile 3 :',q3)
# Out:
# Quartile 1 : 43.0
# Quartile 2 : 65.0
# Quartile 3 : 67.0

# %%
#6. Outliers -> it is a datapoint which is different than the other datapoint (just like a anomly)
#As we seen in box plot (very odd value of data, eg- age of 300 or age of -89)
age = [234,45,78,56,34,23,34,32,45]
import matplotlib.pyplot as plt
plt.boxplot(age)
plt.show()

# %%
#here as we can see that upper far away point is outlier (anomly)

# %% [markdown]
# ![image.png](attachment:1d35c9b2-548f-4011-8739-2025d9a4c00a.png)

# %%
#step 1 --> detect outliers --> plot a boxplot to detect outlier

# %%
age=[21,3,543,34,54,67,34,23,12,45,765]
plt.boxplot(age)
plt.show()

# %%
#in this data there is 2 outliers

# %%
#if we want to remove them its on the data- if the data is like football data where anomly is ronaldo messi etc.
#they are better than other players exceptionally - hence we can't remove them
#we can remove outliers when the data is about credit card sm, mobile etc. 
#hence it depends on data either we have to drop or not (work with outliers)

# %%
#Outliers Removal ->

# %%
#Inter Quartile Range (IQR) ->
#IQR = Q3 - Q1

# %%
#Step to remove outlier
#1. Calculate Q1(25 percentile) and Q3(75 percenntile)
#2. Calculate the IQR = Q3-Q1
#3. Calculate the lower Bound -> Q1 - 1.5IQR
#4. Upper Bound -> Q3 + 1.5IQR
#5. Any value that's below lower bound and above upper bound - we have to remove it!

# %% [markdown]
# ![image.png](attachment:3a86321a-7165-4e65-9188-90f9293bde12.png)
# ![image.png](attachment:f0be8a1a-6655-43a5-9ec7-4b3b7b77817c.png)
# ![image.png](attachment:f6726706-a8aa-4e7e-8535-f53d7eb4b7ae.png)

# %%
#the box remaining is IQR
#upper bound as UB shown in fig, same as lower bound LB 
#we removing lower to lower bound and upper to upper bound so we get normal data!

# %%
#Step 1 ->
Q1 = np.percentile(age,25)
Q3 = np.percentile(age,75)

# %%
#Step 2 ->
IQR = Q3 - Q1
print(IQR)
# Out:
# 38.5

# %%
#Step 3 ->
lower_bound= Q1 - 1.5*IQR
#Step 4 ->
upper_bound= Q3 + 1.5*IQR

# %%
#Step 5 ->
normal_age=[]
for i in age:
    if i<lower_bound or i>upper_bound:
        print("The outlier(s) is :", i)
    else:
        normal_age.append(i)
# Out:
# The outlier(s) is : 543
# The outlier(s) is : 765

# %%
normal_age
# Out:
# [21, 3, 34, 54, 67, 34, 23, 12, 45]

# %%
#outliers are removed! yay! - there is no excess points in data

# %%
#Corelations -> it tells us the relationship between the two variables
#example - age is direction prop to weight (till 18)
# shoe size and marks have no realtion 
#its just a way of checking that two variable are moving together or opposite direction

# %%
#types of corelation
#1. Positive Corelation -> Directly Prop (one value is inc , another also increasing)
 #Experience and salary
#2. Negative Corelation -> Inversly prop - if one is increasing other will decrease
 #Speed and time
#3. Zero Corelation -> No relation
 #Height and Marks
 #Salary and Quality of Apple

# %%
import seaborn as sns
df = sns.load_dataset('iris') #load dataset is inbuilt/own dataset command (this dataset is inside seaborn)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
corre = df.corr(numeric_only = True) #numeric only means float and int
corre
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corre, annot=True,cmap='coolwarm')
plt.show()

# %%
#Types of data ->

#1. Qualitative data / Catogerical data - The type of data that describe catogeries or qualities in meaningful ways
   #it has two parts

     #a. Nominal data -  this type of data can be catogerized but has no specific order. Example- Gender, Race, Religion
     # Fruit = mango , banana, cherry.

     #b. Odinal data -  this type of data can be catogerized and there should be a proper order
     #Example - rating - [bad , avergae, good,very good] or [one star,2 star,3,4,5]



#2. Quantitative data / Numerical data -The type of data that represent numbers and can be calculative
  #it has two parts

     #a. Discrete data -  data can only have a specific value within in a range
     #Example- number of students in a class -> 40

     #a. Continuous data -  data can take any value within a range 
     #b. Height of student - 187.34cm or 187.345454..... cm

# %%
#Normal distribution - in normal distribution we will get it bell shaped curved where the data have same mean median mode.
#Mean == mode == median
data = [15,16,16,17,17,17,18,18,19]
sns.histplot(data, color ='blue',kde=True) #kde = kernal density estimate
plt.show()

# %% [markdown]
# ![image.png](attachment:9a3752d3-d558-4aca-aa48-1b5524547b25.png)

# %%
stats.mean(data)
# Out:
# 17

# %%
stats.median(data)
# Out:
# 17

# %%
stats.mode(data)
# Out:
# 17

# %%
#Skewness -> it will tell me how actually my data is distributed 
#if skewness = 0, symmetric distribution 
#if skewness > 0, Data is right skewed or positive skewed
#f skewnwss < 0, data is left skewed or negative skewed

# %%
from scipy.stats import skew #scipy means scientific python

# %% [markdown]
# Left side and right side is same if i will cut the data to half from center
# ![image.png](attachment:85d31210-922b-43b0-a0ae-265498cff0e2.png)

# %%
#called symmetric skew

# %%
print(skew(data))
# Out:
# 0.0

# %%
#tells data is symmetrical!
data2 = [10,10,10,10,15,18,30]
sns.histplot(data2, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
stats.mode(data2)
# Out:
# 10

# %%
stats.mean(data2)
# Out:
# 14.714285714285714

# %%
stats.median(data2)
# Out:
# 10

# %%
#median = mode =! mean

# %% [markdown]
# ![image.png](attachment:26128a87-e205-4f2a-8773-f5b8defdf0dc.png)

# %%
 print(skew(data2)) #Positive skew
# Out:
# 1.3853437662991548

# %%
data3 = [1,2,3,4,4,4,5,5,6]
sns.histplot(data3, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
stats.mean(data3)
# Out:
# 3.7777777777777777

# %%
stats.mode(data3)
# Out:
# 4

# %%
stats.median(data3)
# Out:
# 4

# %%
print(skew(data3))
# Out:
# -0.4462710526278828

# %%
#it is a negative skewed !

# %% [markdown]
# ![image.png](attachment:ffd9b76b-66d1-4490-ab35-c361970b3a86.png)
